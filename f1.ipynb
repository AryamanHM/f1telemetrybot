# %%
pip install fastf1
# Out:
# Collecting fastf1
#   Downloading fastf1-2.3.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: requests in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (2.27.1)
# Requirement already satisfied: scipy in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.7.3)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (3.5.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.22.1)
# Collecting timple>=0.1.2
#   Downloading timple-0.1.5-py3-none-any.whl (17 kB)
# Collecting thefuzz
#   Downloading thefuzz-0.19.0-py2.py3-none-any.whl (17 kB)
# Collecting requests-cache>=0.8.0
#   Downloading requests_cache-0.9.6-py3-none-any.whl (47 kB)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.4.0)
# Collecting signalr-client-aio
#   Downloading signalr_client_aio-0.0.1.6.2-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->fastf1) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->fastf1) (1.16.0)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: urllib3>=1.25.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (1.26.8)
# Requirement already satisfied: attrs>=21.2 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (21.4.0)
# Collecting cattrs>=1.8
#   Downloading cattrs-22.1.0-py3-none-any.whl (33 kB)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.0rc9-py3-none-any.whl (12 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (2021.10.8)
# Collecting websockets>=4.0.1
#   Downloading websockets-10.3-cp310-cp310-win_amd64.whl (98 kB)
# Installing collected packages: exceptiongroup, websockets, url-normalize, cattrs, appdirs, timple, thefuzz, signalr-client-aio, requests-cache, fastf1
# Successfully installed appdirs-1.4.4 cattrs-22.1.0 exceptiongroup-1.0.0rc9 fastf1-2.3.0 requests-cache-0.9.6 signalr-client-aio-0.0.1.6.2 thefuzz-0.19.0 timple-0.1.5 url-normalize-1.4.3 websockets-10.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\aryam\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import fastf1 as ff1

# %%
#enable the cache
ff1.Cache.enable_cache('cache')

# %%
#Specify the session (no data downloaded yet)
session=ff1.get_session(2022,'Zandvoort','Q')
#download the data
session.load()
# Out:
# core           INFO 	Loading data for Dutch Grand Prix - Qualifying [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for track_status_data. Loading data...
# api            INFO 	Fetching track status data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for car_data. Loading data...
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for position_data. Loading data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for weather_data. Loading data...
# api            INFO 	Fetching weather data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for race_control_messages. Loading data...
# api            INFO 	Fetching race control messages...
# api            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '16',
# 275     LAT           1        True 2022-09-03 13:02:38.497
# 276     LAT           1       False 2022-09-03 13:03:51.850
# 277     LAT           1       False 2022-09-03 13:05:32.600
# 278     LAT           1       False 2022-09-03 13:16:32.726
#
# [5 rows x 27 columns]

# %%
session.laps.pick_driver('LAT').pick_fastest()
# Out:
# Time                      0 days 00:18:51.840000
# DriverNumber                                   6
# LapTime                   0 days 00:01:13.353000
# LapNumber                                      2
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:25.080000
# Sector2Time               0 days 00:00:25.871000
# Sector3Time               0 days 00:00:22.402000
# Sector1SessionTime        0 days 00:18:03.567000
# Sector2SessionTime        0 days 00:18:29.438000
# Sector3SessionTime        0 days 00:18:51.840000
# SpeedI1                                    279.0
# SpeedI2                                    283.0
# SpeedFL                                    311.0
# SpeedST                                    321.0
# IsPersonalBest                              True
# Compound                                    SOFT
# TyreLife                                     2.0
# FreshTyre                                   True
# Stint                                          1
# LapStartTime              0 days 00:17:38.487000
# Team                                    Williams
# Driver                                       LAT
# TrackStatus                                    1
# IsAccurate                                  True
# LapStartDate          2022-09-03 13:02:38.497000
# Name: 275, dtype: object

# %% [markdown]
# Intro to F1 Data Analysis with Python
# Jupyter notebooks have shortcuts
# -N convert cell to markdown
# -A insert cell above
# -DD deletes cell
# -b INSERT CELL Below
# Shift+Enter will run a cell and move on to the next one

# %% [markdown]
# 0.Setting Everything up

# %%
import fastf1 as ff1
from fastf1 import plotting
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.colors import ListedColormap
from matplotlib.collections import LineCollection
# Out:
# font_manager       INFO 	generated new fontManager

# %% [markdown]
# How to install fastf1

# %%
# %pip install fastf1
# Out:
# Requirement already satisfied: fastf1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: scipy in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.7.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.22.1)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (3.5.1)
# Requirement already satisfied: thefuzz in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (0.19.0)
# Requirement already satisfied: timple>=0.1.2 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (0.1.5)
# Requirement already satisfied: signalr-client-aio in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (0.0.1.6.2)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (1.4.0)
# Requirement already satisfied: requests in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (2.27.1)
# Requirement already satisfied: requests-cache>=0.8.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from fastf1) (0.9.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.3->fastf1) (4.29.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->fastf1) (2021.3)
# Requirement already satisfied: attrs>=21.2 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (21.4.0)
# Requirement already satisfied: cattrs>=1.8 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (22.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (1.4.4)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests-cache>=0.8.0->fastf1) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from requests->fastf1) (3.3)
# Requirement already satisfied: websockets>=4.0.1 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from signalr-client-aio->fastf1) (10.3)
# Requirement already satisfied: exceptiongroup in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from cattrs>=1.8->requests-cache>=0.8.0->fastf1) (1.0.0rc9)
# Requirement already satisfied: six>=1.5 in c:\users\aryam\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->fastf1) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Enable the cache
ff1.Cache.enable_cache('cache') #argument is the name of the folder

# %%
#Enable the plotting settings
ff1.plotting.setup_mpl()

# %%
session=ff1.get_session(2022,'Zandvoort','Q')

# %%
session

# %%
session.load()
# Out:
# core           INFO 	Loading data for Dutch Grand Prix - Qualifying [v2.3.0]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '55', '44', '11', '63', '4', '47', '22', '18', '10', '31', '14', '24', '23', '77', '3', '20', '5', '6']

# %% [markdown]
# 1.eXPLORE THE DATA

# %%
session.laps
# Out:
#                       Time DriverNumber                LapTime  LapNumber  \
# 0   0 days 00:21:09.642000            1                    NaT          1
# 1   0 days 00:22:20.959000            1 0 days 00:01:11.317000          2
# 2   0 days 00:24:07.220000            1 0 days 00:01:46.261000          3
# 3   0 days 00:48:49.924000            1                    NaT          4
# 4   0 days 00:50:00.851000            1 0 days 00:01:10.927000          5
# ..                     ...          ...                    ...        ...
# 274 0 days 00:17:38.487000            6                    NaT          1
# 275 0 days 00:18:51.840000            6 0 days 00:01:13.353000          2
# 276 0 days 00:20:32.590000            6 0 days 00:01:40.750000          3
# 277 0 days 00:31:32.716000            6                    NaT          4
# 278 0 days 00:33:27.814000            6 0 days 00:01:55.098000          5
#
#                 PitOutTime              PitInTime            Sector1Time  \
# 0   0 days 00:19:46.866000                    NaT                    NaT
# 1                      NaT                    NaT 0 days 00:00:24.455000
# 2                      NaT 0 days 00:24:03.490000 0 days 00:00:34.813000
# 3   0 days 00:47:27.401000                    NaT                    NaT
# 4                      NaT                    NaT 0 days 00:00:24.529000
# ..                     ...                    ...                    ...
# 274 0 days 00:16:03.595000                    NaT                    NaT
# 275                    NaT                    NaT 0 days 00:00:25.080000
# 276                    NaT 0 days 00:20:31.017000 0 days 00:00:32.807000
# 277 0 days 00:29:56.836000                    NaT                    NaT
# 278                    NaT 0 days 00:33:23.464000 0 days 00:00:24.653000
#
#                Sector2Time            Sector3Time     Sector1SessionTime  ...  \
# 0   0 days 00:00:30.588000 0 days 00:00:22.747000                    NaT  ...
# 1   0 days 00:00:24.776000 0 days 00:00:22.086000 0 days 00:21:34.097000  ...
# 2   0 days 00:00:37.411000 0 days 00:00:34.037000 0 days 00:22:55.772000  ...
# 3   0 days 00:00:29.760000 0 days 00:00:22.891000                    NaT  ...
# 4   0 days 00:00:24.644000 0 days 00:00:21.754000 0 days 00:49:14.453000  ...
# ..                     ...                    ...                    ...  ...
# 274 0 days 00:00:31.119000 0 days 00:00:25.250000                    NaT  ...
# 275 0 days 00:00:25.871000 0 days 00:00:22.402000 0 days 00:18:03.567000  ...
# 276 0 days 00:00:33.179000 0 days 00:00:34.764000 0 days 00:19:24.647000  ...
# 277 0 days 00:00:30.243000 0 days 00:00:26.444000                    NaT  ...
# 278 0 days 00:00:46.173000 0 days 00:00:44.272000 0 days 00:31:57.369000  ...
#
# 238     SOFT      2.0       True      5 0 days 00:56:14.942000  Williams
# 239     SOFT      3.0       True      5 0 days 00:57:26.744000  Williams
#
#      Driver TrackStatus  IsAccurate            LapStartDate
# 224     ALB           1       False 2022-09-03 13:00:58.301
# 225     ALB           1        True 2022-09-03 13:02:31.350
# 226     ALB           1        True 2022-09-03 13:03:44.259
# 227     ALB           1        True 2022-09-03 13:05:34.386
# 228     ALB           1        True 2022-09-03 13:07:14.199
# 229     ALB           1       False 2022-09-03 13:08:26.726
# 230     ALB           1       False 2022-09-03 13:10:03.513
# 231     ALB           1        True 2022-09-03 13:14:12.544
# 232     ALB           1       False 2022-09-03 13:15:24.239
# 233     ALB           5       False 2022-09-03 13:17:06.462
# 234     ALB           1       False 2022-09-03 13:32:05.398
# 235     ALB           1        True 2022-09-03 13:33:34.099
# 236     ALB           1       False 2022-09-03 13:34:46.177
# 237     ALB           1       False 2022-09-03 13:36:27.731
# 238     ALB           1        True 2022-09-03 13:41:14.952
# 239     ALB           1       False 2022-09-03 13:42:26.754
#
# [16 rows x 27 columns]

# %%
laps_alb.pick_fastest()
# Out:
# Time                      0 days 00:57:26.744000
# DriverNumber                                  23
# LapTime                   0 days 00:01:11.802000
# LapNumber                                     15
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:24.660000
# Sector2Time               0 days 00:00:25.274000
# Sector3Time               0 days 00:00:21.868000
# Sector1SessionTime        0 days 00:56:39.602000
# Sector2SessionTime        0 days 00:57:04.876000
# Sector3SessionTime        0 days 00:57:26.744000
# SpeedI1                                    282.0
# SpeedI2                                    286.0
# SpeedFL                                    316.0
# SpeedST                                    322.0
# IsPersonalBest                              True
# Compound                                    SOFT
# TyreLife                                     2.0
# FreshTyre                                   True
# Stint                                          5
# LapStartTime              0 days 00:56:14.942000
# Team                                    Williams
# Driver                                       ALB
# TrackStatus                                    1
# IsAccurate                                  True
# LapStartDate          2022-09-03 13:41:14.952000
# Name: 238, dtype: object

# %%
573/73
# Out:
# 7.8493150684931505

# %%
laps_alb.pick_fastest().get_telemetry()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aryam\OneDrive\Documents\GitHub\F1Analytics\f1.ipynb Cell 23 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aryam/OneDrive/Documents/GitHub/F1Analytics/f1.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> laps_alb.pick_fastest().get_telemetry()
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\fastf1\core.py:2374, in Lap.get_telemetry(self)
#    2370 car_data = self.get_car_data(pad=1, pad_side='both')
#    2372 # calculate driver ahead from from data without padding to
#    2373 # prevent out of bounds errors
# -> 2374 drv_ahead = car_data.iloc[1:-1].add_driver_ahead() \
#    2375     .loc[:, ('DriverAhead', 'DistanceToDriverAhead',
#    2376              'Date', 'Time', 'SessionTime')]
#    2378 car_data = car_data.add_distance().add_relative_distance()
#    2379 car_data = car_data.merge_channels(drv_ahead)
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\fastf1\core.py:746, in Telemetry.add_driver_ahead(self, drop_existing)
#     742 else:
#     743     d = self
#     745 drv_ahead, dist, ref_tel = \
# --> 746     self.calculate_driver_ahead(return_reference=True)
#     748 # calculate driver ahead works with the unmodified source telemetry,
#     749 # therefore it may be necessary to resample the result if self uses
#     750 # a different timebase
#     751 # create a Telemetry object where the calculation results are merged
#     752 # with Date, Time and SessionTime. This is necessary so that the data
#     753 # can be resampled from the reference timebase to the timebase of self
#     754 dtd = ref_tel.loc[:, ('Date', 'Time', 'SessionTime')].join(
#     755     pd.DataFrame({'DriverAhead': drv_ahead,
#     756                   'DistanceToDriverAhead': dist},
#     757                  index=ref_tel.index)
#     758 )
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\fastf1\core.py:943, in Telemetry.calculate_driver_ahead(self, return_reference)
#     940 delta_dst[np.isnan(delta_dst)] = np.inf  # substitute nan with inf, else nan is returned as min
#     941 delta_dst[delta_dst < 0] = np.inf  # remove cars behind so that neg numbers are not returned as min
# --> 943 index_ahead = np.argmin(delta_dst, axis=1)
#     945 drv_ahead = np.array([drv_map[i] for i in index_ahead])
#     946 drv_ahead[np.all(delta_dst == np.inf, axis=1)] = ''  # remove driver from all inf rows
#
# File <__array_function__ internals>:180, in argmin(*args, **kwargs)
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1312, in argmin(a, axis, out, keepdims)
#    1225 """
#    1226 Returns the indices of the minimum values along an axis.
#    1227
#    (...)
#    1309 (2, 1, 4)
#    1310 """
#    1311 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1312 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: attempt to get argmin of an empty sequence

# %% [markdown]
# LETS BUILD SOME PLOTS

# %%
driver_1,driver_2='VET','NOR'

# %%
laps_driver_1=session.laps.pick_driver(driver_1)
laps_driver_2=session.laps.pick_driver(driver_2)

# %%
fastest_driver_1=laps_driver_1.pick_fastest()
fastest_driver_2=laps_driver_2.pick_fastest()

# %%
telemetry_driver_1=fastest_driver_1.get_telemetry()
telemetry_driver_2=fastest_driver_2.get_telemetry()

# %%
delta_time, ref_tel, compare_tel = ff1.utils.delta_time(fastest_driver_1, fastest_driver_2)

# %%
#Identify team color
#laps_driver_1
team_driver_1=laps_driver_1['Team'].iloc[0]
team_driver_2=laps_driver_2['Team'].iloc[0]

color_1=ff1.plotting.team_color(team_driver_1)
color_2=ff1.plotting.team_color(team_driver_2)

# %%
team_driver_1
# Out:
# 'Aston Martin'

# %%
color_1
# Out:
# '#006f62'

# %% [markdown]
# 2.1 Telemtry Bot

# %%
#Set the size of the plot
plt.rcParams['figure.figsize']=[20,15]

#7 plots
#- Delta
#Speed
#Throttle
#Breaking
#Gear
#RPM
#DRS
fig, ax = plt.subplots(7, gridspec_kw={'height_ratios': [1, 3, 2, 1, 1, 2, 1]})

#set the title of the plot
ax[0].title.set_text(f"Telemtry Comparison {driver_1} vs. {driver_2}")

#Subplot 1:The delta
ax[0].plot(ref_tel['Distance'],delta_time,color=color_1)
ax[0].axhline(0)
ax[0].set(ylabel=f"Gap to {driver_2}(s)")

#Subplot 2,Speed
ax[1].plot(telemetry_driver_1['Distance'],telemetry_driver_1['Speed'],label=driver_1,color=color_1)
ax[1].plot(telemetry_driver_2['Distance'],telemetry_driver_2['Speed'],label=driver_1,color=color_2)
ax[1].set(ylabel="Speed")
ax[1].legend(loc="lower right")

"""ax[1].plot(telemetry_driver_1['Distance'], telemetry_driver_1['Speed'], label=driver_1, color=color_1)
ax[1].plot(telemetry_driver_2['Distance'], telemetry_driver_2['Speed'], label=driver_2, color=color_2)
ax[1].set(ylabel="Speed")
ax[1].legend(loc="lower right")
"""
# Subplot 3: Throttle
ax[2].plot(telemetry_driver_1['Distance'], telemetry_driver_1['Throttle'], label=driver_1, color=color_1)
ax[2].plot(telemetry_driver_2['Distance'], telemetry_driver_2['Throttle'], label=driver_2, color=color_2)
ax[2].set(ylabel="Throttle")

#Subplot 4:Breaking
ax[3].plot(telemetry_driver_1['Distance'], telemetry_driver_1['Brake'], label=driver_1, color=color_1)
ax[3].plot(telemetry_driver_2['Distance'], telemetry_driver_2['Brake'], label=driver_2, color=color_2)
ax[3].set(ylabel="Breaking")

#Subplot 5:Gears
ax[4].plot(telemetry_driver_1['Distance'], telemetry_driver_1['nGear'], label=driver_1, color=color_1)
ax[4].plot(telemetry_driver_2['Distance'], telemetry_driver_2['nGear'], label=driver_2, color=color_2)
ax[4].set(ylabel="Gear")

# Subplot 6: RPM
ax[5].plot(telemetry_driver_1['Distance'], telemetry_driver_1['RPM'], label=driver_1, color=color_1)
ax[5].plot(telemetry_driver_2['Distance'], telemetry_driver_2['RPM'], label=driver_2, color=color_2)
ax[5].set(ylabel="RPM")

# Subplot 7: DRS
ax[6].plot(telemetry_driver_1['Distance'], telemetry_driver_1['DRS'], label=driver_1, color=color_1)
ax[6].plot(telemetry_driver_2['Distance'], telemetry_driver_2['DRS'], label=driver_2, color=color_2)
ax[6].set(ylabel="DRS")
# Out:
# [Text(0, 0.5, 'DRS')]

# %% [markdown]
# 2.2 Minisector Comparison

# %%
# Merge the telemetry from both drivers into one dataframe
telemetry_driver_1['Driver'] = driver_1
telemetry_driver_2['Driver'] = driver_2

telemetry = pd.concat([telemetry_driver_1, telemetry_driver_2])

# %%
telemetry
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2022-09-03 13:10:28.984 0 days 00:25:28.974000
# 3   2022-09-03 13:10:29.196 0 days 00:25:29.186000
# 4   2022-09-03 13:10:29.207 0 days 00:25:29.197000
# 5   2022-09-03 13:10:29.356 0 days 00:25:29.346000          18
# 6   2022-09-03 13:10:29.467 0 days 00:25:29.457000          18
# ..                      ...                    ...         ...
# 524 2022-09-03 14:05:58.766 0 days 01:20:58.756000          16
# 525 2022-09-03 14:05:58.768 0 days 01:20:58.758000          16
# 526 2022-09-03 14:05:58.948 0 days 01:20:58.938000          16
# 527 2022-09-03 14:05:58.966 0 days 01:20:58.956000          16
# 528 2022-09-03 14:05:58.968 0 days 01:20:58.958000          16
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2              1626.222500        0 days 00:00:00  11404    309      8
# 3              1626.222500 0 days 00:00:00.212000  11412    310      8
# 4              1626.222500 0 days 00:00:00.223000  11425    310      8
# 5              1626.222500 0 days 00:00:00.372000  11438    310      8
# 6              1624.091250 0 days 00:00:00.483000  11473    311      8
# ..                     ...                    ...    ...    ...    ...
# 524             377.659722 0 days 00:01:10.972000  11075    314      8
# 525             373.493056 0 days 00:01:10.974000  11094    314      8
# 526             369.326389 0 days 00:01:11.154000  11114    314      8
# 527             365.159722 0 days 00:01:11.172000  11134    315      8
# 528             365.159722 0 days 00:01:11.174000  11157    315      8
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2          99  False   12  interpolation     0.045850          0.000011
# 3         100  False   12            car    18.296667          0.004333
# 4          99  False   12            pos    19.243278          0.004557
# 5          99  False   12            car    32.074444          0.007596
# 6          99  False   12            pos    41.678584          0.009871
# ..        ...    ...  ...            ...          ...               ...
# 524        99  False   14            car  4223.100833          0.990135
# 525        99  False   14            pos  4223.275660          0.990176
# 526        99  False   14            pos  4239.024074          0.993868
# 527        99  False   14            car  4240.600833          0.994238
# 528        99  False   14  interpolation  4240.776040          0.994279
#
#       Status    X     Y    Z Driver
# 2    OnTrack  486  3727  537    VET
# 3    OnTrack  556  3896  537    VET
# 4    OnTrack  560  3905  537    VET
# 5    OnTrack  608  4022  536    VET
# 6    OnTrack  645  4112  537    VET
# ..       ...  ...   ...  ...    ...
# 524  OnTrack  439  3609  536    NOR
# 525  OnTrack  440  3611  537    NOR
# 526  OnTrack  499  3757  537    NOR
# 527  OnTrack  505  3772  536    NOR
# 528  OnTrack  505  3773  535    NOR
#
# [1095 rows x 19 columns]

# %%
#calculate the minisectors
num_minisectors=25
total_distance=max(telemetry['Distance'])

# %%
max(telemetry['Distance'])
# Out:
# 4240.776040470659

# %%
# Calculate the minisectors
num_minisectors = 25
total_distance = max(telemetry['Distance'])
minisector_length = total_distance / num_minisectors

# %%
minisectors=[0]

# %%
for i in range(0,(num_minisectors-1)):
    #print(i)
    minisectors.append(minisector_length*(i+1))

# %%
minisectors
# Out:
# [0,
#  169.63104161882634,
#  339.2620832376527,
#  508.89312485647906,
#  678.5241664753054,
#  848.1552080941317,
#  1017.7862497129581,
#  1187.4172913317843,
#  1357.0483329506108,
#  1526.6793745694372,
#  1696.3104161882634,
#  1865.9414578070898,
#  2035.5724994259162,
#  2205.2035410447425,
#  2374.8345826635687,
#  2544.4656242823953,
#  2714.0966659012215,
#  2883.7277075200477,
#  3053.3587491388744,
#  3222.9897907577006,
#  3392.620832376527,
#  3562.2518739953534,
#  3731.8829156141796,
#  3901.513957233006,
#  4071.1449988518325]

# %%
"""
for i in range(0, (num_minisectors - 1)):
    minisectors.append(minisector_length * (i + 1))

"""

# %%
# Assign a minisector number to every row in the telemetry dataframe
telemetry
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2022-09-03 13:10:28.984 0 days 00:25:28.974000
# 3   2022-09-03 13:10:29.196 0 days 00:25:29.186000
# 4   2022-09-03 13:10:29.207 0 days 00:25:29.197000
# 5   2022-09-03 13:10:29.356 0 days 00:25:29.346000          18
# 6   2022-09-03 13:10:29.467 0 days 00:25:29.457000          18
# ..                      ...                    ...         ...
# 524 2022-09-03 14:05:58.766 0 days 01:20:58.756000          16
# 525 2022-09-03 14:05:58.768 0 days 01:20:58.758000          16
# 526 2022-09-03 14:05:58.948 0 days 01:20:58.938000          16
# 527 2022-09-03 14:05:58.966 0 days 01:20:58.956000          16
# 528 2022-09-03 14:05:58.968 0 days 01:20:58.958000          16
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2              1626.222500        0 days 00:00:00  11404    309      8
# 3              1626.222500 0 days 00:00:00.212000  11412    310      8
# 4              1626.222500 0 days 00:00:00.223000  11425    310      8
# 5              1626.222500 0 days 00:00:00.372000  11438    310      8
# 6              1624.091250 0 days 00:00:00.483000  11473    311      8
# ..                     ...                    ...    ...    ...    ...
# 524             377.659722 0 days 00:01:10.972000  11075    314      8
# 525             373.493056 0 days 00:01:10.974000  11094    314      8
# 526             369.326389 0 days 00:01:11.154000  11114    314      8
# 527             365.159722 0 days 00:01:11.172000  11134    315      8
# 528             365.159722 0 days 00:01:11.174000  11157    315      8
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2          99  False   12  interpolation     0.045850          0.000011
# 3         100  False   12            car    18.296667          0.004333
# 4          99  False   12            pos    19.243278          0.004557
# 5          99  False   12            car    32.074444          0.007596
# 6          99  False   12            pos    41.678584          0.009871
# ..        ...    ...  ...            ...          ...               ...
# 524        99  False   14            car  4223.100833          0.990135
# 525        99  False   14            pos  4223.275660          0.990176
# 526        99  False   14            pos  4239.024074          0.993868
# 527        99  False   14            car  4240.600833          0.994238
# 528        99  False   14  interpolation  4240.776040          0.994279
#
#       Status    X     Y    Z Driver
# 2    OnTrack  486  3727  537    VET
# 3    OnTrack  556  3896  537    VET
# 4    OnTrack  560  3905  537    VET
# 5    OnTrack  608  4022  536    VET
# 6    OnTrack  645  4112  537    VET
# ..       ...  ...   ...  ...    ...
# 524  OnTrack  439  3609  536    NOR
# 525  OnTrack  440  3611  537    NOR
# 526  OnTrack  499  3757  537    NOR
# 527  OnTrack  505  3772  536    NOR
# 528  OnTrack  505  3773  535    NOR
#
# [1095 rows x 19 columns]

# %%
minisectors
# Out:
# [0,
#  169.63104161882634,
#  339.2620832376527,
#  508.89312485647906,
#  678.5241664753054,
#  848.1552080941317,
#  1017.7862497129581,
#  1187.4172913317843,
#  1357.0483329506108,
#  1526.6793745694372,
#  1696.3104161882634,
#  1865.9414578070898,
#  2035.5724994259162,
#  2205.2035410447425,
#  2374.8345826635687,
#  2544.4656242823953,
#  2714.0966659012215,
#  2883.7277075200477,
#  3053.3587491388744,
#  3222.9897907577006,
#  3392.620832376527,
#  3562.2518739953534,
#  3731.8829156141796,
#  3901.513957233006,
#  4071.1449988518325]

# %%
# Assign a minisector number to every row in the telemetry dataframe
telemetry['Minisector'] = telemetry['Distance'].apply(
    lambda dist: (
        int((dist // minisector_length) + 1)
    )
)

# %%
telemetry
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2022-09-03 13:10:28.984 0 days 00:25:28.974000
# 3   2022-09-03 13:10:29.196 0 days 00:25:29.186000
# 4   2022-09-03 13:10:29.207 0 days 00:25:29.197000
# 5   2022-09-03 13:10:29.356 0 days 00:25:29.346000          18
# 6   2022-09-03 13:10:29.467 0 days 00:25:29.457000          18
# ..                      ...                    ...         ...
# 524 2022-09-03 14:05:58.766 0 days 01:20:58.756000          16
# 525 2022-09-03 14:05:58.768 0 days 01:20:58.758000          16
# 526 2022-09-03 14:05:58.948 0 days 01:20:58.938000          16
# 527 2022-09-03 14:05:58.966 0 days 01:20:58.956000          16
# 528 2022-09-03 14:05:58.968 0 days 01:20:58.958000          16
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2              1626.222500        0 days 00:00:00  11404    309      8
# 3              1626.222500 0 days 00:00:00.212000  11412    310      8
# 4              1626.222500 0 days 00:00:00.223000  11425    310      8
# 5              1626.222500 0 days 00:00:00.372000  11438    310      8
# 6              1624.091250 0 days 00:00:00.483000  11473    311      8
# ..                     ...                    ...    ...    ...    ...
# 524             377.659722 0 days 00:01:10.972000  11075    314      8
# 525             373.493056 0 days 00:01:10.974000  11094    314      8
# 526             369.326389 0 days 00:01:11.154000  11114    314      8
# 527             365.159722 0 days 00:01:11.172000  11134    315      8
# 528             365.159722 0 days 00:01:11.174000  11157    315      8
#
#      Throttle  Brake  DRS         Source     Distance  RelativeDistance  \
# 2          99  False   12  interpolation     0.045850          0.000011
# 3         100  False   12            car    18.296667          0.004333
# 4          99  False   12            pos    19.243278          0.004557
# 5          99  False   12            car    32.074444          0.007596
# 6          99  False   12            pos    41.678584          0.009871
# ..        ...    ...  ...            ...          ...               ...
# 524        99  False   14            car  4223.100833          0.990135
# 525        99  False   14            pos  4223.275660          0.990176
# 526        99  False   14            pos  4239.024074          0.993868
# 527        99  False   14            car  4240.600833          0.994238
# 528        99  False   14  interpolation  4240.776040          0.994279
#
#       Status    X     Y    Z Driver  Minisector
# 2    OnTrack  486  3727  537    VET           1
# 3    OnTrack  556  3896  537    VET           1
# 4    OnTrack  560  3905  537    VET           1
# 5    OnTrack  608  4022  536    VET           1
# 6    OnTrack  645  4112  537    VET           1
# ..       ...  ...   ...  ...    ...         ...
# 524  OnTrack  439  3609  536    NOR          25
# 525  OnTrack  440  3611  537    NOR          25
# 526  OnTrack  499  3757  537    NOR          25
# 527  OnTrack  505  3772  536    NOR          25
# 528  OnTrack  505  3773  535    NOR          26
#
# [1095 rows x 20 columns]

# %%
#Calculate minisector speeds per driver
average_speed = telemetry.groupby(['Minisector', 'Driver'])['Speed'].mean().reset_index()
average_speed
# Out:
#     Minisector Driver       Speed
# 0            1    NOR  314.882353
# 1            1    VET  312.375000
# 2            2    NOR  215.680000
# 3            2    VET  207.000000
# 4            3    NOR  152.241379
# 5            3    VET  155.903226
# 6            4    NOR  227.476190
# 7            4    VET  219.434783
# 8            5    NOR  164.620690
# 9            5    VET  158.700000
# 10           6    NOR  194.720000
# 11           6    VET  184.791667
# 12           7    NOR  256.400000
# 13           7    VET  251.666667
# 14           8    NOR  276.235294
# 15           8    VET  273.421053
# 16           9    NOR  280.411765
# 17           9    VET  278.266667
# 18          10    NOR  268.117647
# 19          10    VET  264.333333
# 20          11    NOR  255.277778
# 21          11    VET  257.882353
# 22          12    NOR  254.882353
# 23          12    VET  241.550000
# 24          13    NOR  215.761905
# 25          13    VET  203.000000
# 26          14    NOR  139.687500
# 27          14    VET  139.242424
# 28          15    NOR  129.521739
# 29          15    VET  138.848485
# 30          16    NOR  210.133333
# 31          16    VET  197.454545
# 32          17    NOR  264.250000
# 33          17    VET  266.263158
# 34          18    NOR  239.250000
# 35          18    VET  223.520000
# 36          19    NOR  118.054054
# 37          19    VET  114.071429
# 38          20    NOR  203.666667
# 39          20    VET  207.913043
# 40          21    NOR  204.875000
# 41          21    VET  197.666667
# 42          22    NOR  241.526316
# 43          22    VET  244.368421
# 44          23    NOR  274.882353
# 45          23    VET  275.526316
# 46          24    NOR  295.416667
# 47          24    VET  297.250000
# 48          25    NOR  310.444444
# 49          25    VET  307.666667
# 50          26    NOR  315.000000

# %%
# Per minisector, find the fastest driver
fastest_driver = average_speed.loc[average_speed.groupby(['Minisector'])['Speed'].idxmax()]
fastest_driver = fastest_driver[['Minisector', 'Driver']].rename(columns={'Driver': 'Fastest_driver'})

# %%
fastest_driver
# Out:
#     Minisector Fastest_driver
# 0            1            NOR
# 2            2            NOR
# 5            3            VET
# 6            4            NOR
# 8            5            NOR
# 10           6            NOR
# 12           7            NOR
# 14           8            NOR
# 16           9            NOR
# 18          10            NOR
# 21          11            VET
# 22          12            NOR
# 24          13            NOR
# 26          14            NOR
# 29          15            VET
# 30          16            NOR
# 33          17            VET
# 34          18            NOR
# 36          19            NOR
# 39          20            VET
# 40          21            NOR
# 43          22            VET
# 45          23            VET
# 47          24            VET
# 48          25            NOR
# 50          26            NOR

# %%
# Merge the fastest_driver dataframe to the telemetry dataframe on minisector
telemetry = telemetry.merge(fastest_driver, on=['Minisector'])
telemetry = telemetry.sort_values(by=['Distance'])
telemetry
# Out:
#                         Date            SessionTime DriverAhead  \
# 0    2022-09-03 13:10:28.984 0 days 00:25:28.974000
# 16   2022-09-03 14:04:47.794 0 days 01:19:47.784000
# 17   2022-09-03 14:04:47.965 0 days 01:19:47.955000
# 1    2022-09-03 13:10:29.196 0 days 00:25:29.186000
# 18   2022-09-03 14:04:48.008 0 days 01:19:47.998000
# ...                      ...                    ...         ...
# 1090 2022-09-03 14:05:58.766 0 days 01:20:58.756000          16
# 1091 2022-09-03 14:05:58.768 0 days 01:20:58.758000          16
# 1092 2022-09-03 14:05:58.948 0 days 01:20:58.938000          16
# 1093 2022-09-03 14:05:58.966 0 days 01:20:58.956000          16
# 1094 2022-09-03 14:05:58.968 0 days 01:20:58.958000          16
#
#       DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 0               1626.222500        0 days 00:00:00  11404    309      8
# 16               410.428333        0 days 00:00:00  11058    313      8
# 17               410.428333 0 days 00:00:00.171000  11072    314      8
# 1               1626.222500 0 days 00:00:00.212000  11412    310      8
# 18               410.428333 0 days 00:00:00.214000  11063    314      8
# ...                     ...                    ...    ...    ...    ...
# 1090             377.659722 0 days 00:01:10.972000  11075    314      8
# 1091             373.493056 0 days 00:01:10.974000  11094    314      8
# 1092             369.326389 0 days 00:01:11.154000  11114    314      8
# 1093             365.159722 0 days 00:01:11.172000  11134    315      8
# 1094             365.159722 0 days 00:01:11.174000  11157    315      8
#
#       Throttle  Brake  ...         Source     Distance  RelativeDistance  \
# 0           99  False  ...  interpolation     0.045850          0.000011
# 16          99  False  ...  interpolation     0.060591          0.000014
# 17          99  False  ...            car    14.975556          0.003511
# 1          100  False  ...            car    18.296667          0.004333
# 18          99  False  ...            pos    18.726086          0.004390
# ...        ...    ...  ...            ...          ...               ...
# 1090        99  False  ...            car  4223.100833          0.990135
# 1091        99  False  ...            pos  4223.275660          0.990176
# 1092        99  False  ...            pos  4239.024074          0.993868
# 1093        99  False  ...            car  4240.600833          0.994238
# 1094        99  False  ...  interpolation  4240.776040          0.994279
#
#        Status    X     Y    Z  Driver Minisector  Fastest_driver
# 0     OnTrack  486  3727  537     VET          1             NOR
# 16    OnTrack  512  3789  537     NOR          1             NOR
# 17    OnTrack  589  3976  537     NOR          1             NOR
# 1     OnTrack  556  3896  537     VET          1             NOR
# 18    OnTrack  604  4013  537     NOR          1             NOR
# ...       ...  ...   ...  ...     ...        ...             ...
# 1090  OnTrack  439  3609  536     NOR         25             NOR
# 1091  OnTrack  440  3611  537     NOR         25             NOR
# 1092  OnTrack  499  3757  537     NOR         25             NOR
# 1093  OnTrack  505  3772  536     NOR         25             NOR
# 1094  OnTrack  505  3773  535     NOR         26             NOR
#
# [1095 rows x 21 columns]

# %%
# Since our plot can only work with integers, we need to convert the driver abbreviations to integers (1 or 2)
telemetry.loc[telemetry['Fastest_driver'] == driver_1, 'Fastest_driver_int'] = 1
telemetry.loc[telemetry['Fastest_driver'] == driver_2, 'Fastest_driver_int'] = 2
telemetry
# Out:
#                         Date            SessionTime DriverAhead  \
# 0    2022-09-03 13:10:28.984 0 days 00:25:28.974000
# 16   2022-09-03 14:04:47.794 0 days 01:19:47.784000
# 17   2022-09-03 14:04:47.965 0 days 01:19:47.955000
# 1    2022-09-03 13:10:29.196 0 days 00:25:29.186000
# 18   2022-09-03 14:04:48.008 0 days 01:19:47.998000
# ...                      ...                    ...         ...
# 1090 2022-09-03 14:05:58.766 0 days 01:20:58.756000          16
# 1091 2022-09-03 14:05:58.768 0 days 01:20:58.758000          16
# 1092 2022-09-03 14:05:58.948 0 days 01:20:58.938000          16
# 1093 2022-09-03 14:05:58.966 0 days 01:20:58.956000          16
# 1094 2022-09-03 14:05:58.968 0 days 01:20:58.958000          16
#
#       DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 0               1626.222500        0 days 00:00:00  11404    309      8
# 16               410.428333        0 days 00:00:00  11058    313      8
# 17               410.428333 0 days 00:00:00.171000  11072    314      8
# 1               1626.222500 0 days 00:00:00.212000  11412    310      8
# 18               410.428333 0 days 00:00:00.214000  11063    314      8
# ...                     ...                    ...    ...    ...    ...
# 1090             377.659722 0 days 00:01:10.972000  11075    314      8
# 1091             373.493056 0 days 00:01:10.974000  11094    314      8
# 1092             369.326389 0 days 00:01:11.154000  11114    314      8
# 1093             365.159722 0 days 00:01:11.172000  11134    315      8
# 1094             365.159722 0 days 00:01:11.174000  11157    315      8
#
#       Throttle  Brake  ...     Distance RelativeDistance   Status    X     Y  \
# 0           99  False  ...     0.045850         0.000011  OnTrack  486  3727
# 16          99  False  ...     0.060591         0.000014  OnTrack  512  3789
# 17          99  False  ...    14.975556         0.003511  OnTrack  589  3976
# 1          100  False  ...    18.296667         0.004333  OnTrack  556  3896
# 18          99  False  ...    18.726086         0.004390  OnTrack  604  4013
# ...        ...    ...  ...          ...              ...      ...  ...   ...
# 1090        99  False  ...  4223.100833         0.990135  OnTrack  439  3609
# 1091        99  False  ...  4223.275660         0.990176  OnTrack  440  3611
# 1092        99  False  ...  4239.024074         0.993868  OnTrack  499  3757
# 1093        99  False  ...  4240.600833         0.994238  OnTrack  505  3772
# 1094        99  False  ...  4240.776040         0.994279  OnTrack  505  3773
#
#         Z  Driver  Minisector Fastest_driver  Fastest_driver_int
# 0     537     VET           1            NOR                 2.0
# 16    537     NOR           1            NOR                 2.0
# 17    537     NOR           1            NOR                 2.0
# 1     537     VET           1            NOR                 2.0
# 18    537     NOR           1            NOR                 2.0
# ...   ...     ...         ...            ...                 ...
# 1090  536     NOR          25            NOR                 2.0
# 1091  537     NOR          25            NOR                 2.0
# 1092  537     NOR          25            NOR                 2.0
# 1093  536     NOR          25            NOR                 2.0
# 1094  535     NOR          26            NOR                 2.0
#
# [1095 rows x 22 columns]

# %%
# Get the x and y coordinates 
x = np.array(telemetry['X'].values)
y = np.array(telemetry['Y'].values)

# %%
x
# Out:
# array([486, 512, 589, ..., 499, 505, 505], dtype=int64)

# %%
y
# Out:
# array([3727, 3789, 3976, ..., 3757, 3772, 3773], dtype=int64)

# %%
# Convert the coordinates to points, and then concat them into segments
points = np.array([x, y]).T.reshape(-1, 1, 2)

segments = np.concatenate([points[:-1], points[1:]], axis=1)
fastest_driver_array = telemetry['Fastest_driver_int'].to_numpy().astype(float)

# %%
segments
# Out:
# array([[[ 486, 3727],
#         [ 512, 3789]],
#
#        [[ 512, 3789],
#         [ 589, 3976]],
#
#        [[ 589, 3976],
#         [ 556, 3896]],
#
#        ...,
#
#        [[ 440, 3611],
#         [ 499, 3757]],
#
#        [[ 499, 3757],
#         [ 505, 3772]],
#
#        [[ 505, 3772],
#         [ 505, 3773]]], dtype=int64)

# %%
# The segments we just created can now be colored according to the fastest driver in a minisector
cmap = ListedColormap([color_1, color_2])
lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
lc_comp.set_array(fastest_driver_array)
lc_comp.set_linewidth(5)

# %%
# Create the plot
plt.rcParams['figure.figsize'] = [18, 10]

plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.box(False)
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

# Add a colorbar for as legend
cbar = plt.colorbar(mappable=lc_comp, boundaries=np.arange(1,4))
cbar.set_ticks(np.arange(1.5, 9.5))
cbar.set_ticklabels([driver_1, driver_2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aryam\OneDrive\Documents\GitHub\F1Analytics\f1.ipynb Cell 60 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/aryam/OneDrive/Documents/GitHub/F1Analytics/f1.ipynb#Y125sZmlsZQ%3D%3D?line=9'>10</a> cbar = plt.colorbar(mappable=lc_comp, boundaries=np.arange(1,4))
#      <a href='vscode-notebook-cell:/c%3A/Users/aryam/OneDrive/Documents/GitHub/F1Analytics/f1.ipynb#Y125sZmlsZQ%3D%3D?line=10'>11</a> cbar.set_ticks(np.arange(1.5, 9.5))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aryam/OneDrive/Documents/GitHub/F1Analytics/f1.ipynb#Y125sZmlsZQ%3D%3D?line=11'>12</a> cbar.set_ticklabels([driver_1, driver_2])
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\colorbar.py:925, in Colorbar.set_ticklabels(self, ticklabels, update_ticks, minor, **kwargs)
#     890 @_api.delete_parameter("3.5", "update_ticks")
#     891 def set_ticklabels(self, ticklabels, update_ticks=True, *, minor=False,
#     892                    **kwargs):
#     893     """
#     894     Set tick labels.
#     895
#    (...)
#     923         `.Text` properties for the labels.
#     924     """
# --> 925     self._long_axis().set_ticklabels(ticklabels, minor=minor, **kwargs)
#
# File c:\Users\aryam\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716 if isinstance(locator, mticker.FixedLocator):
#    1717     # Passing [] as a list of ticklabels is often used as a way to
#    1718     # remove all tick labels, so only error for > 0 ticklabels
#    1719     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720         raise ValueError(
#    1721             "The number of FixedLocator locations"
#    1722             f" ({len(locator.locs)}), usually from a call to"
#    1723             " set_ticks, does not match"
#    1724             f" the number of ticklabels ({len(ticklabels)}).")
#    1725     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1726     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (8), usually from a call to set_ticks, does not match the number of ticklabels (2).
